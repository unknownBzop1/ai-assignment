# %%
import numpy as np
import pandas as pd
import os

# %%
path = 'C:/PycharmProjects/revamped/ai-assignment'

image_labels_df = pd.read_csv(os.path.join(path, 'Data_Entry_2017_v2020.csv'))
image_labels_df
# Out:
#              Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0       00000001_000.png            Cardiomegaly            0           1
# 1       00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2       00000001_002.png   Cardiomegaly|Effusion            2           1
# 3       00000002_000.png              No Finding            0           2
# 4       00000003_001.png                  Hernia            0           3
# ...                  ...                     ...          ...         ...
# 112115  00030801_001.png          Mass|Pneumonia            1       30801
# 112116  00030802_000.png              No Finding            0       30802
# 112117  00030803_000.png              No Finding            0       30803
# 112118  00030804_000.png              No Finding            0       30804
# 112119  00030805_000.png              No Finding            0       30805
#
#         Patient Age Patient Sex View Position  OriginalImage[Width  Height]  \
# 0                57           M            PA                 2682     2749
# 1                58           M            PA                 2894     2729
# 2                58           M            PA                 2500     2048
# 3                80           M            PA                 2500     2048
# 4                74           F            PA                 2500     2048
# ...             ...         ...           ...                  ...      ...
# 112115           38           M            PA                 2048     2500
# 112116           28           M            PA                 2048     2500
# 112117           42           F            PA                 2048     2500
# 112118           29           F            PA                 2048     2500
# 112119           26           M            PA                 2048     2500
#
#         OriginalImagePixelSpacing[x     y]
# 0                             0.143  0.143
# 1                             0.143  0.143
# 2                             0.168  0.168
# 3                             0.171  0.171
# 4                             0.168  0.168
# ...                             ...    ...
# 112115                        0.168  0.168
# 112116                        0.168  0.168
# 112117                        0.168  0.168
# 112118                        0.168  0.168
# 112119                        0.171  0.171
#
# [112120 rows x 11 columns]

# %%
image_labels_df.query('`Finding Labels` == \'No Finding\'')
# Out:
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 3       00000002_000.png     No Finding            0           2           80
# 13      00000005_000.png     No Finding            0           5           69
# 14      00000005_001.png     No Finding            1           5           69
# 15      00000005_002.png     No Finding            2           5           69
# 16      00000005_003.png     No Finding            3           5           69
# ...                  ...            ...          ...         ...          ...
# 112114  00030801_000.png     No Finding            0       30801           38
# 112116  00030802_000.png     No Finding            0       30802           28
# 112117  00030803_000.png     No Finding            0       30803           42
# 112118  00030804_000.png     No Finding            0       30804           29
# 112119  00030805_000.png     No Finding            0       30805           26
#
#        Patient Sex View Position  OriginalImage[Width  Height]  \
# 3                M            PA                 2500     2048
# 13               F            PA                 2048     2500
# 14               F            AP                 2500     2048
# 15               F            AP                 2500     2048
# 16               F            PA                 2992     2991
# ...            ...           ...                  ...      ...
# 112114           M            PA                 2500     2048
# 112116           M            PA                 2048     2500
# 112117           F            PA                 2048     2500
# 112118           F            PA                 2048     2500
# 112119           M            PA                 2048     2500
#
#         OriginalImagePixelSpacing[x     y]
# 3                             0.171  0.171
# 13                            0.168  0.168
# 14                            0.168  0.168
# 15                            0.168  0.168
# 16                            0.143  0.143
# ...                             ...    ...
# 112114                        0.168  0.168
# 112116                        0.168  0.168
# 112117                        0.168  0.168
# 112118                        0.168  0.168
# 112119                        0.171  0.171
#
# [60361 rows x 11 columns]

# %%
image_labels_df['label_set'] = image_labels_df['Finding Labels'].apply(lambda labels: set(labels.split('|')))

# %%
from functools import reduce

labels: set = reduce(lambda x, y: x.union(y), image_labels_df['label_set'])

# %%
for label in labels:
    print(label, image_labels_df[image_labels_df['label_set'] == {label}].shape)
# Out:
# Cardiomegaly (1093, 12)
# Pleural_Thickening (1126, 12)
# Infiltration (9547, 12)
# Effusion (3955, 12)
# Fibrosis (727, 12)
# Hernia (110, 12)
# Atelectasis (4215, 12)
# No Finding (60361, 12)
# Consolidation (1310, 12)
# Mass (2139, 12)
# Nodule (2705, 12)
# Pneumothorax (2194, 12)
# Edema (628, 12)
# Pneumonia (322, 12)
# Emphysema (892, 12)

# %%
pneumothorax_df = image_labels_df.query('`Finding Labels` == \'Pneumothorax\'')
pneumothorax_df
# Out:
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 49      00000013_033.png   Pneumothorax           11          13           56
# 52      00000013_036.png   Pneumothorax           14          13           56
# 55      00000013_039.png   Pneumothorax           17          13           56
# 74      00000013_011.png   Pneumothorax           36          13           60
# 75      00000013_012.png   Pneumothorax           37          13           60
# ...                  ...            ...          ...         ...          ...
# 111812  00030636_009.png   Pneumothorax            9       30636           45
# 111813  00030636_010.png   Pneumothorax           10       30636           45
# 111839  00030637_010.png   Pneumothorax           10       30637           48
# 111841  00030637_012.png   Pneumothorax           12       30637           48
# 112040  00030753_000.png   Pneumothorax            0       30753           54
#
#        Patient Sex View Position  OriginalImage[Width  Height]  \
# 49               M            PA                 2946     2991
# 52               M            PA                 2952     2968
# 55               M            PA                 2992     2991
# 74               M            AP                 3056     2544
# 75               M            AP                 3056     2544
# ...            ...           ...                  ...      ...
# 111812           M            AP                 3056     2544
# 111813           M            PA                 2021     2021
# 111839           M            PA                 2021     2021
# 111841           M            PA                 2021     2021
# 112040           F            AP                 3056     2544
#
#         OriginalImagePixelSpacing[x        y]
# 49                         0.143000  0.143000
# 52                         0.143000  0.143000
# 55                         0.143000  0.143000
# 74                         0.139000  0.139000
# 75                         0.139000  0.139000
# ...                             ...       ...
# 111812                     0.139000  0.139000
# 111813                     0.194311  0.194311
# 111839                     0.194311  0.194311
# 111841                     0.194311  0.194311
# 112040                     0.139000  0.139000
#
# [2194 rows x 11 columns]

# %%
image_labels_df.query('`Finding Labels` == \'Pneumothorax\'').groupby(['Patient Sex', 'View Position']).agg({'Image Index': 'count'}).reset_index()
# Out:
#   Patient Sex View Position  Image Index
# 0           F            AP          288
# 1           F            PA          905
# 2           M            AP          400
# 3           M            PA          601

# %%
f_ap_count = len(image_labels_df.query('`Finding Labels` == \'Pneumothorax\' and `Patient Sex` == \'F\' and `View Position` == \'AP\'')['Image Index'].unique())
f_pa_count = len(image_labels_df.query('`Finding Labels` == \'Pneumothorax\' and `Patient Sex` == \'F\' and `View Position` == \'PA\'')['Image Index'].unique())
m_ap_count = len(image_labels_df.query('`Finding Labels` == \'Pneumothorax\' and `Patient Sex` == \'M\' and `View Position` == \'AP\'')['Image Index'].unique())
m_pa_count = len(image_labels_df.query('`Finding Labels` == \'Pneumothorax\' and `Patient Sex` == \'M\' and `View Position` == \'PA\'')['Image Index'].unique())

# %%
no_finding_df = image_labels_df.query('`Finding Labels` == \'No Finding\'')
no_finding_f_ap_samples = no_finding_df.query('`Patient Sex` == \'F\' and `View Position` == \'AP\'').sample(n=f_ap_count, random_state=0, replace=False)
no_finding_f_pa_samples = no_finding_df.query('`Patient Sex` == \'F\' and `View Position` == \'PA\'').sample(n=f_pa_count, random_state=0, replace=False)
no_finding_m_ap_samples = no_finding_df.query('`Patient Sex` == \'M\' and `View Position` == \'AP\'').sample(n=m_ap_count, random_state=0, replace=False)
no_finding_m_pa_samples = no_finding_df.query('`Patient Sex` == \'M\' and `View Position` == \'PA\'').sample(n=m_pa_count, random_state=0, replace=False)

# %%
no_finding_samples = pd.concat([no_finding_f_ap_samples, no_finding_f_pa_samples, no_finding_m_ap_samples, no_finding_m_pa_samples])
no_finding_samples
# Out:
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 68601   00016937_012.png     No Finding            3       16937           51
# 54150   00013623_007.png     No Finding            7       13623           46
# 80769   00019852_001.png     No Finding            1       19852           40
# 47714   00012094_031.png     No Finding           31       12094           63
# 56985   00014149_036.png     No Finding           36       14149           59
# ...                  ...            ...          ...         ...          ...
# 104880  00028125_001.png     No Finding            1       28125           50
# 49584   00012585_014.png     No Finding           14       12585           54
# 24732   00006499_001.png     No Finding            0        6499           29
# 26897   00007023_002.png     No Finding            2        7023           57
# 74583   00018308_008.png     No Finding            8       18308           60
#
#        Patient Sex View Position  OriginalImage[Width  Height]  \
# 68601            F            AP                 2500     2048
# 54150            F            AP                 2500     2048
# 80769            F            AP                 3056     2544
# 47714            F            AP                 2500     2048
# 56985            F            AP                 2500     2048
# ...            ...           ...                  ...      ...
# 104880           M            PA                 2021     2020
# 49584            M            PA                 2992     2991
# 24732            M            PA                 2048     2500
# 26897            M            PA                 2500     2048
# 74583            M            PA                 2992     2991
#
#         OriginalImagePixelSpacing[x        y]
# 68601                      0.168000  0.168000
# 54150                      0.168000  0.168000
# 80769                      0.139000  0.139000
# 47714                      0.168000  0.168000
# 56985                      0.168000  0.168000
# ...                             ...       ...
# 104880                     0.194311  0.194311
# 49584                      0.143000  0.143000
# 24732                      0.171000  0.171000
# 26897                      0.168000  0.168000
# 74583                      0.143000  0.143000
#
# [2194 rows x 11 columns]

# %%
training_test_df = pd.concat([no_finding_samples, pneumothorax_df])
training_test_df
# Out:
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 68601   00016937_012.png     No Finding            3       16937           51
# 54150   00013623_007.png     No Finding            7       13623           46
# 80769   00019852_001.png     No Finding            1       19852           40
# 47714   00012094_031.png     No Finding           31       12094           63
# 56985   00014149_036.png     No Finding           36       14149           59
# ...                  ...            ...          ...         ...          ...
# 111812  00030636_009.png   Pneumothorax            9       30636           45
# 111813  00030636_010.png   Pneumothorax           10       30636           45
# 111839  00030637_010.png   Pneumothorax           10       30637           48
# 111841  00030637_012.png   Pneumothorax           12       30637           48
# 112040  00030753_000.png   Pneumothorax            0       30753           54
#
#        Patient Sex View Position  OriginalImage[Width  Height]  \
# 68601            F            AP                 2500     2048
# 54150            F            AP                 2500     2048
# 80769            F            AP                 3056     2544
# 47714            F            AP                 2500     2048
# 56985            F            AP                 2500     2048
# ...            ...           ...                  ...      ...
# 111812           M            AP                 3056     2544
# 111813           M            PA                 2021     2021
# 111839           M            PA                 2021     2021
# 111841           M            PA                 2021     2021
# 112040           F            AP                 3056     2544
#
#         OriginalImagePixelSpacing[x        y]
# 68601                      0.168000  0.168000
# 54150                      0.168000  0.168000
# 80769                      0.139000  0.139000
# 47714                      0.168000  0.168000
# 56985                      0.168000  0.168000
# ...                             ...       ...
# 111812                     0.139000  0.139000
# 111813                     0.194311  0.194311
# 111839                     0.194311  0.194311
# 111841                     0.194311  0.194311
# 112040                     0.139000  0.139000
#
# [4388 rows x 11 columns]

# %%
no_finding_df
# Out:
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 3       00000002_000.png     No Finding            0           2           80
# 13      00000005_000.png     No Finding            0           5           69
# 14      00000005_001.png     No Finding            1           5           69
# 15      00000005_002.png     No Finding            2           5           69
# 16      00000005_003.png     No Finding            3           5           69
# ...                  ...            ...          ...         ...          ...
# 112114  00030801_000.png     No Finding            0       30801           38
# 112116  00030802_000.png     No Finding            0       30802           28
# 112117  00030803_000.png     No Finding            0       30803           42
# 112118  00030804_000.png     No Finding            0       30804           29
# 112119  00030805_000.png     No Finding            0       30805           26
#
#        Patient Sex View Position  OriginalImage[Width  Height]  \
# 3                M            PA                 2500     2048
# 13               F            PA                 2048     2500
# 14               F            AP                 2500     2048
# 15               F            AP                 2500     2048
# 16               F            PA                 2992     2991
# ...            ...           ...                  ...      ...
# 112114           M            PA                 2500     2048
# 112116           M            PA                 2048     2500
# 112117           F            PA                 2048     2500
# 112118           F            PA                 2048     2500
# 112119           M            PA                 2048     2500
#
#         OriginalImagePixelSpacing[x     y]
# 3                             0.171  0.171
# 13                            0.168  0.168
# 14                            0.168  0.168
# 15                            0.168  0.168
# 16                            0.143  0.143
# ...                             ...    ...
# 112114                        0.168  0.168
# 112116                        0.168  0.168
# 112117                        0.168  0.168
# 112118                        0.168  0.168
# 112119                        0.171  0.171
#
# [60361 rows x 11 columns]

# %%
training_test_df.to_csv(os.path.join(path, 'base_data.csv'), index=False)
